# %% [markdown]
# # REA

# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://ia340-fall2025-nv/Crime_Data_from_2020_to_Present.csv') # load the data from s3
df.head() #show the top 5 rows
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# ...

# %%
df.shape
# Out:
# (1004991, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Data columns (total 28 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1004991 non-null  int64
#  1   Date Rptd       1004991 non-null  object
#  2   DATE OCC        1004991 non-null  object
#  3   TIME OCC        1004991 non-null  int64
#  4   AREA            1004991 non-null  int64
#  5   AREA NAME       1004991 non-null  object
#  6   Rpt Dist No     1004991 non-null  int64
#  7   Part 1-2        1004991 non-null  int64
#  8   Crm Cd          1004991 non-null  int64
#  9   Crm Cd Desc     1004991 non-null  object
#  10  Mocodes         853372 non-null   object
#  11  Vict Age        1004991 non-null  int64
#  12  Vict Sex        860347 non-null   object
#  13  Vict Descent    860335 non-null   object
#  14  Premis Cd       1004975 non-null  float64
#  15  Premis Desc     1004403 non-null  object
# ...

# %%
df.describe()
# Out:
#               DR_NO      TIME OCC          AREA   Rpt Dist No      Part 1-2  \
# count  1.004991e+06  1.004991e+06  1.004991e+06  1.004991e+06  1.004991e+06
# mean   2.202215e+08  1.339900e+03  1.069174e+01  1.115633e+03  1.400348e+00
# std    1.319718e+07  6.510613e+02  6.110255e+00  6.111605e+02  4.899691e-01
# min    8.170000e+02  1.000000e+00  1.000000e+00  1.010000e+02  1.000000e+00
# 25%    2.106169e+08  9.000000e+02  5.000000e+00  5.870000e+02  1.000000e+00
# 50%    2.209159e+08  1.420000e+03  1.100000e+01  1.139000e+03  1.000000e+00
# 75%    2.311103e+08  1.900000e+03  1.600000e+01  1.613000e+03  2.000000e+00
# max    2.521041e+08  2.359000e+03  2.100000e+01  2.199000e+03  2.000000e+00
#
#              Crm Cd      Vict Age     Premis Cd  Weapon Used Cd      Crm Cd 1  \
# count  1.004991e+06  1.004991e+06  1.004975e+06   327247.000000  1.004980e+06
# mean   5.001568e+02  2.891706e+01  3.056201e+02      363.955300  4.999174e+02
# ...

# %% [markdown]
# There are about 1,000,000 rows (crime reports), and 28 columns in this dataset.
# Some columns that texist are unique record number, time of occurrence, area, and victim age.
# Some first impressions of this dataset is that it contains very detailed information about crime, it has a mix of catergorical and numerical data, and it does contain some missing values.

# %%
#rename columns
df = df.rename(columns={"LOCATION": "Address"})
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# ...

# %%
df.isnull().sum() #show the number of rows containing null value
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA                    0
# AREA NAME               0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            151619
# Vict Age                0
# Vict Sex           144644
# Vict Descent       144656
# Premis Cd              16
# Premis Desc           588
# Weapon Used Cd     677744
# Weapon Desc        677744
# Status                  1
# Status Desc             0
# Crm Cd 1               11
# Crm Cd 2           935831
# Crm Cd 3          1002677
# Crm Cd 4          1004927
# Address                 0
# Cross Street       850755
# LAT                     0
# LON                     0
# dtype: int64

# %%
df = df.dropna() #drop null values
df.isnull().sum()
# Out:
# DR_NO             0
# Date Rptd         0
# DATE OCC          0
# TIME OCC          0
# AREA              0
# AREA NAME         0
# Rpt Dist No       0
# Part 1-2          0
# Crm Cd            0
# Crm Cd Desc       0
# Mocodes           0
# Vict Age          0
# Vict Sex          0
# Vict Descent      0
# Premis Cd         0
# Premis Desc       0
# Weapon Used Cd    0
# Weapon Desc       0
# Status            0
# Status Desc       0
# Crm Cd 1          0
# Crm Cd 2          0
# Crm Cd 3          0
# Crm Cd 4          0
# Address           0
# Cross Street      0
# LAT               0
# LON               0
# dtype: int64

# %% [markdown]
# I renamed the "LOCATION" column to "Address." I found 5,591,213 missing values. I handled these missing values by dropping the null values.

# %%
df['AREA NAME']
# Out:
# 27751        Mission
# 134755     Hollywood
# 363765     Hollywood
# 372524       Rampart
# 490101     Hollywood
# 537834    Devonshire
# 586003       Pacific
# 728576    Devonshire
# 809419       Mission
# 934749       Mission
# Name: AREA NAME, dtype: object

# %%
df.sort_values(by='Crm Cd')
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 363765  210617136  10/08/2021 12:00:00 AM  10/07/2021 12:00:00 AM      1950
# 537834  221718232  12/25/2022 12:00:00 AM  12/25/2022 12:00:00 AM      1150
# 728576  231717599  11/15/2023 12:00:00 AM  11/15/2023 12:00:00 AM       400
# 372524  210209196  05/08/2021 12:00:00 AM  05/08/2021 12:00:00 AM       230
# 809419  231915572  10/21/2023 12:00:00 AM  10/21/2023 12:00:00 AM         1
# 27751   201904032  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM      2135
# 134755  200613424  08/02/2020 12:00:00 AM  08/02/2020 12:00:00 AM      2030
# 934749  241905348  02/04/2024 12:00:00 AM  02/03/2024 12:00:00 AM      1100
# 490101  220600626  04/27/2022 12:00:00 AM  04/23/2022 12:00:00 AM      2300
# 586003  221401314  11/10/2022 12:00:00 AM  11/10/2022 12:00:00 AM      2117
#
#         AREA   AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 363765     6   Hollywood          659         1     121
# ...

# %%
df[0:7]
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 27751   201904032  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM      2135
# 134755  200613424  08/02/2020 12:00:00 AM  08/02/2020 12:00:00 AM      2030
# 363765  210617136  10/08/2021 12:00:00 AM  10/07/2021 12:00:00 AM      1950
# 372524  210209196  05/08/2021 12:00:00 AM  05/08/2021 12:00:00 AM       230
# 490101  220600626  04/27/2022 12:00:00 AM  04/23/2022 12:00:00 AM      2300
# 537834  221718232  12/25/2022 12:00:00 AM  12/25/2022 12:00:00 AM      1150
# 586003  221401314  11/10/2022 12:00:00 AM  11/10/2022 12:00:00 AM      2117
#
#         AREA   AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 27751     19     Mission         1924         1     761
# 134755     6   Hollywood          657         1     761
# 363765     6   Hollywood          659         1     121
# 372524     2     Rampart          279         1     210
# 490101     6   Hollywood          646         1     821
# ...

# %%
df[df['Rpt Dist No'] >600]
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 27751   201904032  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM      2135
# 134755  200613424  08/02/2020 12:00:00 AM  08/02/2020 12:00:00 AM      2030
# 363765  210617136  10/08/2021 12:00:00 AM  10/07/2021 12:00:00 AM      1950
# 490101  220600626  04/27/2022 12:00:00 AM  04/23/2022 12:00:00 AM      2300
# 537834  221718232  12/25/2022 12:00:00 AM  12/25/2022 12:00:00 AM      1150
# 586003  221401314  11/10/2022 12:00:00 AM  11/10/2022 12:00:00 AM      2117
# 728576  231717599  11/15/2023 12:00:00 AM  11/15/2023 12:00:00 AM       400
# 809419  231915572  10/21/2023 12:00:00 AM  10/21/2023 12:00:00 AM         1
# 934749  241905348  02/04/2024 12:00:00 AM  02/03/2024 12:00:00 AM      1100
#
#         AREA   AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 27751     19     Mission         1924         1     761
# 134755     6   Hollywood          657         1     761
# ...

# %% [markdown]
# I selected to display the Area Name column. I sorted all the rows by Crm Cd, and sliced 7 rows. I filtered the rows by only displaying Rpt Dist No greater then 600.

# %%
import pandas as pd

crime_data = pd.read_csv("s3://ia340-fall2025-nv/Crime_Data_from_2020_to_Present.csv")

area_counts = crime_data.groupby("AREA NAME").size()

print(area_counts.sort_values(ascending=False).head(10))
# Out:
# AREA NAME
# Central        69670
# 77th Street    61758
# Pacific        59514
# Southwest      57441
# Hollywood      52429
# N Hollywood    51107
# Olympic        50071
# Southeast      49936
# Newton         49177
# Wilshire       48239
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

crime_data = pd.read_csv("s3://ia340-fall2025-nv/Crime_Data_from_2020_to_Present.csv")

plt.figure(figsize=(10,6))
plt.bar(crime_counts.index, crime_counts.values)


plt.title("Top 10 Most Common Crime Types")
plt.xlabel("Crime Type")
plt.ylabel("Number of Reports")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


crime_data = pd.read_csv("s3://ia340-fall2025-nv/Crime_Data_from_2020_to_Present.csv")

plt.plot(monthly_crimes.index.astype(str), monthly_crimes.values,figsize=(10, 5))
plt.title("Crimes Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Crimes")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 7
#       2 import matplotlib.pyplot as plt
#       5 crime_data = pd.read_csv("s3://ia340-fall2025-nv/Crime_Data_from_2020_to_Present.csv")
# ----> 7 plt.plot(monthly_crimes.index.astype(str), monthly_crimes.values,figsize=(10, 5))
#       8 plt.title("Crimes Over Time")
#       9 plt.xlabel("Year")
#
# File ~/anaconda3/envs/python3/lib/python3.10/site-packages/matplotlib/pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)
#    3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
# ...

# %% [markdown]
# For the first (Bar) graph, the data is showing crime type and the number of reports of that crime within the past 20 years.
# The graph is showing that cehicle theft is the most common crime, and that overall there are fewer violent crimes in the top range of numbers.
#
# For the scatter plot, the data is showing the number of crimes per year for the past 20 years.
# The plot shows that there is a noticable drop in crime rates starting in 2023. It can also be inferred that the small rises and falls are possible changes in seasonal trends.
